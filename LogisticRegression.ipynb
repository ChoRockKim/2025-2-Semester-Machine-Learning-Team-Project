# %% [markdown]
# <a href="https://colab.research.google.com/github/ChoRockKim/2025-2-Semester-Machine-Learning-Team-Project/blob/main/LogisticRegression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
# 깃허브에서 AI vs Human 데이터 다운로드
# !git clone https://github.com/panagiotisanagnostou/AI-GA

# CSV 파일 다운로드
data = pd.read_csv('/content/AI-GA/ai-ga-dataset.csv')

data.head()
# Out:
# Cloning into 'AI-GA'...
# remote: Enumerating objects: 21, done.
# remote: Counting objects: 100% (21/21), done.
# remote: Compressing objects: 100% (15/15), done.
# remote: Total 21 (delta 9), reused 14 (delta 5), pack-reused 0 (from 0)
# Receiving objects: 100% (21/21), 13.84 MiB | 10.02 MiB/s, done.
# Resolving deltas: 100% (9/9), done.
#                                                title  \
# 0  Clinical features of culture-proven Mycoplasma...
# 1  Nitric oxide: a pro-inflammatory mediator in l...
# 2    Surfactant protein-D and pulmonary host defense
# 3               Role of endothelin-1 in lung disease
# 4  Gene expression in epithelial cells in respons...
#
#                                             abstract  label
# 0  OBJECTIVE: This retrospective chart review des...      0
# 1  Inflammatory diseases of the respiratory tract...      0
# 2  Surfactant protein-D (SP-D) participates in th...      0
# 3  Endothelin-1 (ET-1) is a 21 amino acid peptide...      0
# 4  Respiratory syncytial virus (RSV) and pneumoni...      0

# %%
# nltk 라이브러리로 전처리 준비
import nltk
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer

nltk.download('stopwords')
nltk.download('punkt')
nltk.download('punkt_tab')

# 전처리 로직 적용
# 토크나이징, 소문자 변환, stopwords 제거, 알파벳/숫자 필터링, stemming
def preprocess_data(text):
  tokens = nltk.word_tokenize(text)
  stemmer = PorterStemmer()
  processed_tokens = [stemmer.stem(token.lower()) for token in tokens if token.isalnum() and token.lower() not in stopwords.words('english')]

  return ' '.join(processed_tokens)

data['full_text'] = data['title'] + ' ' + data['abstract']
data['processed_text'] = data['full_text'].apply(preprocess_data) # full_text를 전처리
data.head()
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
#                                                title  \
# 0  Clinical features of culture-proven Mycoplasma...
# 1  Nitric oxide: a pro-inflammatory mediator in l...
# 2    Surfactant protein-D and pulmonary host defense
# 3               Role of endothelin-1 in lung disease
# 4  Gene expression in epithelial cells in respons...
#
#                                             abstract  label  \
# 0  OBJECTIVE: This retrospective chart review des...      0
# 1  Inflammatory diseases of the respiratory tract...      0
# 2  Surfactant protein-D (SP-D) participates in th...      0
# 3  Endothelin-1 (ET-1) is a 21 amino acid peptide...      0
# 4  Respiratory syncytial virus (RSV) and pneumoni...      0
#
#                                            full_text  \
# 0  Clinical features of culture-proven Mycoplasma...
# 1  Nitric oxide: a pro-inflammatory mediator in l...
# 2  Surfactant protein-D and pulmonary host defens...
# 3  Role of endothelin-1 in lung disease Endotheli...
# 4  Gene expression in epithelial cells in respons...
#
#                                       processed_text
# 0  clinic featur mycoplasma pneumonia infect king...
# 1  nitric oxid mediat lung diseas inflammatori di...
# 2  surfact pulmonari host defens surfact particip...
# 3  role lung diseas 21 amino acid peptid divers b...
# 4  gene express epitheli cell respons pneumoviru ...

# %%
from sklearn.model_selection import train_test_split

# 전체 데이터를 훈련 세트와 테스트 세트로 분할
train_data, temp_test_data = train_test_split(data, test_size=0.3, random_state=42)

# 임시 테스트 세트를 검증 세트와 테스트 세트 (각각 10%) 로 분할
val_data, test_data = train_test_split(temp_test_data, test_size=0.5, random_state=42)

print(f"훈련 데이터셋 크기: {len(train_data)}")
print(f"검증 데이터셋 크기: {len(val_data)}")
print(f"테스트 데이터셋 크기: {len(test_data)}")
# Out:
# 훈련 데이터셋 크기: 20063
# 검증 데이터셋 크기: 4299
# 테스트 데이터셋 크기: 4300

# %%
# Bag-of-Words 방식으로 벡터화 (Only 단어의 빈도수)

from sklearn.feature_extraction.text import CountVectorizer

# bigram 으로 고려, 노이즈 제거(최소 2회 이상 어휘만 포함)
vectorizer = CountVectorizer(ngram_range=(1, 2), min_df= 5)
X = vectorizer.fit_transform(train_data['processed_text'])

# 텍스트문서에 나타난 어휘의 집합
print(vectorizer.vocabulary_)
# 어휘가 몇 개인지
print(len(vectorizer.vocabulary_))

#
train_vectors = vectorizer.transform(train_data['processed_text'])
val_vectors = vectorizer.transform(val_data['processed_text'])
test_vectors = vectorizer.transform(test_data['processed_text'])

print(train_vectors[0])
# Out:
# {'bilater': 9033, 'massiv': 44344, 'pneumonia': 54981, 'unusu': 78195, 'manifest': 44155, 'puumala': 59846, 'hantaviru': 32155, 'infect': 37435, 'renal': 62524, 'involv': 40353, 'due': 22461, 'european': 25662, 'viru': 80700, 'puuv': 59848, 'frequent': 29702, 'pulmonari': 59711, 'quit': 60075, 'rare': 60338, 'present': 56718, 'male': 43877, 'atyp': 7750, 'clinic': 13039, 'acut': 2178, 'gross': 31587, 'minim': 46459, 'sever': 67214, 'case': 10596, 'highlight': 33201, 'consid': 15639, 'differenti': 20730, 'diagnosi': 20161, 'unusu manifest': 78200, 'hantaviru infect': 32156, 'renal involv': 62534, 'puumala viru': 59847, 'pulmonari involv': 59741, 'rare present': 60355, 'present male': 56866, 'clinic present': 13161, 'present acut': 56722, 'involv sever': 40469, 'sever pulmonari': 67398, 'pulmonari manifest': 59744, 'infect case': 37519, 'case highlight': 10670, 'infect consid': 37557, 'consid differenti': 15660, 'differenti diagnosi': 20739, 'atyp pneumonia': 7753, 'dynam': 22683, '35': 731, 'year': 82830, 'old': 50413, 'freshwat': 29734, 'mitig': 46549, 'wetland': 81989, 'southeastern': 68951, 'new': 49034, 'ecolog': 22975, 'success': 71616, 'compensatori': 14281, 'project': 58273, 'come': 13807, 'question': 60024, 'base': 8345, 'monitor': 47253, 'studi': 70870, 'past': 52541, 'decad': 18267, 'given': 31082, 'restor': 63995, 'may': 44448, 'requir': 62932, 'mani': 44092, 'converg': 16404, 'desir': 19201, 'outcom': 51315, 'pattern': 53570, 'increas': 36502, 'abil': 1057, 'fulli': 29786, 'evalu': 25684, 'guid': 31927, 'adapt': 2275, 'manag': 43951, 'need': 48499, 'ha': 32076, 'construct': 15825, 'abandon': 1035, 'impact': 35315, 'associ': 7179, 'properti': 58500, 'expans': 26764, 'build': 9850, 'upon': 78227, 'prior': 57392, '1992': 299, '2002': 344, 'conduct': 15304, 'floral': 28903, 'survey': 72421, '2020': 496, 'compar': 14024, 'result': 64016, 'document': 22090, 'veget': 80182, 'trend': 76773, 'time': 75087, 'addit': 2330, 'avian': 8020, 'commun': 13936, 'throughout': 74889, 'grow': 31847, 'season': 66254, 'measur': 44778, 'habitat': 32088, 'qualiti': 59911, 'plant': 54778, 'mirror': 46515, 'nativ': 48343, 'domin': 22155, 'speci': 69021, 'composit': 14632, 'stabil': 69662, 'rate': 60403, 'turnov': 77076, 'declin': 18342, 'nearli': 48430, 'half': 32127, '17': 211, 'research': 63063, 'specif': 69175, 'site': 68416, 'better': 8903, 'understand': 77670, 'creat': 16993, 'long': 43093, 'frame': 29621, 'develop': 19687, 'red': 61254, 'meadow': 44718, 'high': 32926, 'rich': 64894, 'attribut': 7738, 'activ': 1812, 'topograph': 75648, 'heterogen': 32871, 'seed': 66376, 'bank': 8306, 'applic': 5944, 'origin': 51128, 'open': 50672, 'water': 81558, 'herbac': 32808, 'cover': 16941, 'woodi': 82570, 'support': 72102, 'divers': 21936, 'includ': 36174, '11': 77, 'depend': 18905, 'although': 4220, 'full': 29770, 'area': 6477, 'lost': 43186, 'structur': 70689, 'complex': 14356, 'effect': 23090, 'provid': 59252, 'function': 29805, 'valu': 79665, 'system': 72907, '35 year': 735, 'year old': 82938, 'base monitor': 8442, 'monitor studi': 47295, 'studi past': 71202, 'past decad': 52549, 'may requir': 44636, 'mani year': 44154, 'desir outcom': 19204, 'outcom monitor': 51442, 'pattern may': 53617, 'may increas': 44570, 'increas abil': 36506, 'fulli evalu': 29791, 'evalu success': 25907, 'adapt manag': 2294, 'manag need': 44018, 'mitig impact': 46558, 'build upon': 9863, 'upon prior': 78279, 'prior evalu': 57404, 'compar result': 14181, 'result prior': 64290, 'trend time': 76798, 'time addit': 75094, 'commun throughout': 14001, 'grow season': 31864, 'plant commun': 54783, 'domin speci': 22157, 'speci composit': 69045, 'plant speci': 54802, 'measur success': 44948, 'nearli half': 48432, '17 year': 216, 'year research': 82963, 'research consid': 63118, 'specif site': 69391, 'better understand': 8976, 'long time': 43116, 'time frame': 75171, 'requir develop': 62963, 'high speci': 33013, 'speci rich': 69132, 'support divers': 72128, 'commun includ': 13964, ' ...
# 83198
# <Compressed Sparse Row sparse matrix of dtype 'int64'
# 	with 49 stored elements and shape (1, 83198)>
#   Coords	Values
#   (0, 2178)	1
#   (0, 7750)	2
#   (0, 7753)	1
#   (0, 9033)	1
#   (0, 10596)	1
#   (0, 10670)	1
#   (0, 13039)	1
#   (0, 13161)	1
#   (0, 15639)	1
#   (0, 15660)	1
#   (0, 20161)	1
#   (0, 20730)	1
#   (0, 20739)	1
#   (0, 22461)	1
#   (0, 25662)	1
#   (0, 29702)	1
#   (0, 31587)	1
#   (0, 32155)	2
#   (0, 32156)	2
#   (0, 33201)	1
#   (0, 37435)	4
#   (0, 37519)	1
#   (0, 37557)	1
#   (0, 40353)	3
#   (0, 40469)	1
#   (0, 43877)	1
#   (0, 44155)	2
#   (0, 44344)	1
#   (0, 46459)	1
#   (0, 54981)	2
#   (0, 56718)	2
#   (0, 56722)	1
#   (0, 56866)	1
#   (0, 59711)	3
#   (0, 59741)	1
#   (0, 59744)	1
#   (0, 59846)	2
#   (0, 59847)	1
#   (0, 59848)	3
#   (0, 60075)	1
#   (0, 60338)	1
#   (0, 60355)	1
#   (0, 62524)	2
#   (0, 62534)	2
#   (0, 67214)	1
#   (0, 67398)	1
#   (0, 78195)	1
#   (0, 78200)	1
#   (0, 80700)	1

# %%
# 분류모델, 로지스틱 회귀로 훈련
from sklearn.linear_model import LogisticRegression

model = LogisticRegression(max_iter=1000, C=0.1)

# 모델 훈련 (훈련 데이터의 BOW 벡터와 레이블 사용)
# train_data['label']은 타겟 변수
model.fit(train_vectors, train_data['label'])

print("모델 훈련 완료.")
# Out:
# 모델 훈련 완료.

# %%
# 5. 모델 평가

from sklearn.metrics import accuracy_score, classification_report

# 검증 데이터에 대한 예측
val_predictions = model.predict(val_vectors)

# 검증 데이터에 대한 정확도 평가
accuracy = accuracy_score(val_data['label'], val_predictions)
print(f"검증 데이터 정확도: {accuracy:.4f}")

# 검증 데이터에 대한 상세 평가 리포트
print("\n검증 데이터 Classification Report:")
print(classification_report(val_data['label'], val_predictions))

test_predictions = model.predict(test_vectors)
test_accuracy = accuracy_score(test_data['label'], test_predictions)
print(f"\n테스트 데이터 정확도: {test_accuracy:.4f}")
print("\n테스트 데이터 Classification Report:")
print(classification_report(test_data['label'], test_predictions))
# Out:
# 검증 데이터 정확도: 0.9714
#
# 검증 데이터 Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.97      0.97      0.97      2130
#            1       0.97      0.98      0.97      2169
#
#     accuracy                           0.97      4299
#    macro avg       0.97      0.97      0.97      4299
# weighted avg       0.97      0.97      0.97      4299
#
#
# 테스트 데이터 정확도: 0.9667
#
# 테스트 데이터 Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.97      0.96      0.97      2139
#            1       0.96      0.97      0.97      2161
#
#     accuracy                           0.97      4300
#    macro avg       0.97      0.97      0.97      4300
# weighted avg       0.97      0.97      0.97      4300

# %%
from sklearn.metrics import confusion_matrix

# Calculate the confusion matrix for the test data
cm = confusion_matrix(test_data['label'], test_predictions)

# Extract TP, TN, FP, FN
tn, fp, fn, tp = cm.ravel()

print(f"Confusion Matrix:\n{cm}")
print(f"\nTrue Positives (TP): {tp}")
print(f"False Positives (FP): {fp}")
print(f"True Negatives (TN): {tn}")
print(f"False Negatives (FN): {fn}")
# Out:
# Confusion Matrix:
# [[2058   81]
#  [  62 2099]]
#
# True Positives (TP): 2099
# False Positives (FP): 81
# True Negatives (TN): 2058
# False Negatives (FN): 62

# %%
results_df = test_data.copy()
results_df['prediction'] = test_predictions

# Extract TN, FP, FN, TP cases
tn_cases = results_df[(results_df['label'] == 0) & (results_df['prediction'] == 0)]
fp_cases = results_df[(results_df['label'] == 0) & (results_df['prediction'] == 1)]
fn_cases = results_df[(results_df['label'] == 1) & (results_df['prediction'] == 0)]
tp_cases = results_df[(results_df['label'] == 1) & (results_df['prediction'] == 1)]

print(f"Total test samples: {len(results_df)}")
print(f"True Negatives (TN): {len(tn_cases)}\n{tn_cases.head()}\n")
print(f"False Positives (FP): {len(fp_cases)}\n{fp_cases.head()}\n")
print(f"False Negatives (FN): {len(fn_cases)}\n{fn_cases.head()}\n")
print(f"True Positives (TP): {len(tp_cases)}\n{tp_cases.head()}\n")
# Out:
# Total test samples: 4300
# True Negatives (TN): 2058
#                                                    title  \
# 3922   A pilot study—genetic diversity and population...
# 2527   Severe acute respiratory infection caused by s...
# 928    Evolutionary Dynamics of the Interferon-Induce...
# 17980  National reporting of deaths after enhanced Eb...
# 18246  Overview of the Development, Impacts, and Chal...
#
#                                                 abstract  label  \
# 3922   BACKGROUND: The Hindu Kush and Karakoram mount...      0
# 2527   In October 2016, a severe infection with swine...      0
# 928    Vertebrate interferon-induced transmembrane (I...      0
# 17980  BACKGROUND: Sierra Leone experienced the large...      0
# 18246  Safety, efficacy, and cost-effectiveness are p...      0
#
#                                                full_text  \
# 3922   A pilot study—genetic diversity and population...
# 2527   Severe acute respiratory infection caused by s...
# 928    Evolutionary Dynamics of the Interferon-Induce...
# 17980  National reporting of deaths after enhanced Eb...
# 18246  Overview of the Development, Impacts, and Chal...
#
#                                           processed_text  prediction
# 3922   pilot divers popul structur snow leopard pakis...           0
# 2527   sever acut respiratori infect caus swine influ...           0
# 928    evolutionari dynam transmembran gene famili ve...           0
# 17980  nation report death enhanc ebola surveil sierr...           0
# 18246  overview develop impact challeng oral rotaviru...           0
#
# False Positives (FP): 81
#                                                    title  \
# 4836   Network immunization and virus propagation in ...
# 8309   Comparing MMPI-2-Restructured Form Scores by S...
# 22446  Compatibility and Safety Implications Associat...
# 3949   The socio-economic distribution of exposure to...
# 1303   Stimulation of ribosomal frameshifting by RNA ...
#
#                                                 abstract  label  \
# 4836   Network immunization strategies have emerged a...      0
# 8309   This study compares profiles of Minnesota Mult...      0
# 22446  Over the past decade, international organizati...      0
# 3949   Socio-economic factors are widely believed to ...      0
# 1303   Guanine-rich sequences can fold into four-stra...      0
#
#                                                full_text  \
# 4836   Network immunization and virus propagation in ...
# 8309   Comparing MMPI-2-Restructured Form Scores by S...
# 22446  Compatibility and Safety Implications Associat...
# 3949   The socio-economic distribution of exposure to...
# 1303   Stimulation of ribosomal frameshifting by RNA ...
#
#                                           processed_text  prediction
# 4836   network immun viru propag email network experi...           1
# 8309   compar form score servic era veteran assess wi...           1
# 22446  compat safeti implic associ interfac medic dev...           1
# 3949   distribut exposur ebola survey evid liberia si...           1
# 1303   stimul ribosom frameshift rna structur sequenc...           1
#
# False Negatives (FN): 62
#                                                    title  \
# 11012  Inhibition of cell adhesion to the virus by sy...
# 21555  Type I Interferon α/β Receptor-Mediated Signal...
# 18473  Development of eco-friendly, self-cleaning, an...
# 8902   Rationality of 17 cities’ public perception of...
# 11291  AVP‐IC(50)Pred: Multiple machine learning tech...
#
#                                                 abstract  label  \
# 11012  \n\nThis study provides insight into the possi...      1
# 21555  \n\nTitle: Type I Interferon α/β Receptor-Medi...      1
# 18473  \n\n\nThis paper reports the development of an...      1
# 8902   \n\nThis study examines the rationality of pub...      1
# 11291  \n\nThis article presents a novel machine lear...      1
#
#                                                full_text  \
# 11012  Inhibition of cell adhesion to the virus by sy...
# 21555  Type I Interferon α/β Receptor-Mediated Signal...
# 18473  Development of eco-friendly, self-cleaning, an...
# 8902   Rationality of 17 cities’ public perception of...
# 11291  AVP‐IC(50)Pred: Multiple machine learning tech...
#
#                                           processed_text  prediction
# 11012  inhibit cell adhes viru synthet peptid fiber k...           0
# 21555  type interferon signal neg regul antivir cytok...           0
# 18473  develop antibacteri membran elimin chromium vi...           0
# 8902   ration 17 citi public percept sar predict mode...           0
# 11291  50 pred multipl machin learn predict peptid an...           0
#
# True Positives (TP): 2099
#                                                    title  \
# 21192  Forced solar gazing—a common technique of tort...
# 26204  The acceptance and impact of Google Classroom ...
# 15459  Investigation of Fugitive Aerosols Released in...
# 10511  Yeast Two-Hybrid Screens: Improvement of Array...
# 26363  Weight stigma experiences and self-exclusion f...
#
#                                                 abstract  label  \
# 21192  \n\nThe use of torture as an instrument to inf...      1
# 26204  \n\nThis article reports on a research conduct...      1
# 15459  \n\nThis paper presents an investigation into ...      1
# 10511  \n\nThis study explores how N- and C-terminall...      1
# 26363  \n\nWeight stigma and self-exclusion from spor...      1
#
#                                                full_text  \
# 21192  Forced solar gazing—a common technique of tort...
# 26204  The acceptance and impact of Google Classroom ...
# 15459  Investigation of Fugitive Aerosols Released in...
# 10511  Yeast Two-Hybrid Screens: Improvement of Array...
# 26363  Weight stigma experiences and self-exclusion f...
#
#                                           processed_text  prediction
# 21192  forc solar common techniqu tortur use tortur i...           1
# 26204  accept impact googl classroom integr clinic pa...           1
# 15459  investig fugit aerosol releas environ therapi ...           1
# 10511  yeast screen improv screen result tag fusion p...           1
# 26363  weight stigma experi sport exercis set among p...           1

# %%
model_name = 'LogisticRegression'
layers = 0  # Assuming 0 layers for a simple Logistic Regression model
epochs = 1000  # From the LogisticRegression max_iter parameter
seed = 42 # From the train_test_split random_state parameter

# Save TN cases
tn_filename = f"{model_name}_00_layer{layers}_epoch{epochs}_sd{seed}_TN.csv"
tn_cases.to_csv(tn_filename, index=False)
print(f"Saved TN cases to {tn_filename}")

# Save FP cases
fp_filename = f"{model_name}_01_layer{layers}_epoch{epochs}_sd{seed}_FP.csv"
fp_cases.to_csv(fp_filename, index=False)
print(f"Saved FP cases to {fp_filename}")

# Save FN cases
fn_filename = f"{model_name}_10_layer{layers}_epoch{epochs}_sd{seed}_FN.csv"
fn_cases.to_csv(fn_filename, index=False)
print(f"Saved FN cases to {fn_filename}")

# Save TP cases
tp_filename = f"{model_name}_11_layer{layers}_epoch{epochs}_sd{seed}_TP.csv"
tp_cases.to_csv(tp_filename, index=False)
print(f"Saved TP cases to {tp_filename}")
# Out:
# Saved TN cases to LogisticRegression_00_layer0_epoch1000_sd42_TN.csv
# Saved FP cases to LogisticRegression_01_layer0_epoch1000_sd42_FP.csv
# Saved FN cases to LogisticRegression_10_layer0_epoch1000_sd42_FN.csv
# Saved TP cases to LogisticRegression_11_layer0_epoch1000_sd42_TP.csv
